# %%
import pandas as pd
from pandas.io.html import read_html
from selenium import webdriver
from datetime import datetime

# %%
pages = ['https://www.f1fantasytracker.com/sentiment-tracker.html']
ids = ['constructorTable', 'driverTable']

# %%
from webdriver_manager.firefox import GeckoDriverManager

driver = webdriver.Firefox(executable_path=GeckoDriverManager().install())
# driver.get()
# Out:
# ====== WebDriver manager ======
# Current firefox version is 101.0
# Get LATEST geckodriver version for 101.0 firefox
# Driver [/Users/michaelmatney/.wdm/drivers/geckodriver/macos/v0.31.0/geckodriver] found in cache

# %%
frames = []

for page in pages:
    driver.get(page)
    for id in ids:
        table = driver.find_element_by_id(id)
        data = read_html(table.get_attribute('outerHTML'))
        frames.append(data[0])

# %%
driver.close()
driver.quit()

# %%
frames[0]
# Out:
#            Team  12 Hour  3 Hour  Latest Sentiment
# 0    AlphaTauri        1       0       0       93%
# 1       Ferrari        1       0       0       74%
# 2  Aston Martin        0       0       0       48%
# 3      Williams        1       0       0       -2%
# 4      Mercedes        0       0       0      -12%
# 5       Mclaren        0       0       0      -34%
# 6          Haas       -1       0       0      -50%
# 7        Alpine       -1      -1       0      -64%
# 8      Red Bull        2       1       0      -76%
# 9    Alfa Romeo       -3       0       0      -81%

# %%
frames[1]
# Out:
#                                  Driver  12 Hour  3 Hour  Latest Sentiment
# 0       Lance Stroll  STR  Aston Martin        9       0       0       92%
# 1      Valtteri Bottas  BOT  Alfa Romeo       10       3       0       82%
# 2         Pierre Gasly  GAS  AlphaTauri        0       0       0       80%
# 3            Mick Schumacher  SCH  Haas       -5      -1       0       72%
# 4            Lando Norris  NOR  Mclaren       -2       0       0       40%
# 5         George Russell  RUS  Mercedes       24       7       1       37%
# 6         Charles Leclerc  LEC  Ferrari        1       1       0       32%
# 7          Guanyu Zhou  ZHO  Alfa Romeo       21      11       2       21%
# 8            Kevin Magnussen  MAG  Haas        0       0       0       15%
# 9         Max Verstappen  VER  Red Bull        0       0       0        2%
# 10         Fernando Alonso  ALO  Alpine        0       0       0        0%
# 11            Esteban Ocon  OCO  Alpine       -1      -1       0       -1%
# 12           SAI  Carlos Sainz  Ferrari       -1       0       0      -31%
# 13       Nicholas Latifi  LAT  Williams        0       0       0      -31%
# 14          Sergio Perez  PER  Red Bull      -21      -7      -1      -46%
# 15        Yuki Tsunoda  TSU  AlphaTauri       -1      -1       0      -51%
# 16       Daniel Ricciardo  RIC  Mclaren       -5      -2      -1      -54%
# 17        Lewis Hamilton  HAM  Mercedes        0       0       0      -77%
# 18  Sebastian Vettel  VET  Aston Martin        0      -1       0      -79%
# 19            Alex Albon  ALB  Williams      -19      -6      -1      -83%

# %%
for frame in frames:
    frame['ts'] = (datetime.now()).strftime('%Y-%m-%d %H:%M:%S')

# %%
frames[0]
# Out:
#            Team  12 Hour  3 Hour  Latest Sentiment                   ts
# 0    AlphaTauri        1       0       0       93%  2022-06-06 21:16:02
# 1       Ferrari        1       0       0       74%  2022-06-06 21:16:02
# 2  Aston Martin        0       0       0       48%  2022-06-06 21:16:02
# 3      Williams        1       0       0       -2%  2022-06-06 21:16:02
# 4      Mercedes        0       0       0      -12%  2022-06-06 21:16:02
# 5       Mclaren        0       0       0      -34%  2022-06-06 21:16:02
# 6          Haas       -1       0       0      -50%  2022-06-06 21:16:02
# 7        Alpine       -1      -1       0      -64%  2022-06-06 21:16:02
# 8      Red Bull        2       1       0      -76%  2022-06-06 21:16:02
# 9    Alfa Romeo       -3       0       0      -81%  2022-06-06 21:16:02

# %% [markdown]
# ## Write Data

# %%
frame_labels = ['team_sent', 'driver_sent']

for i, frame in enumerate(frames):
    frame.to_csv(f'./data/raw/sent/{frame_labels[i]}-{datetime.now():%Y-%m-%d.%H%M%S}.csv', sep='|')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [15], in <cell line: 3>()
#       1 frame_labels = ['team_sent', 'driver_sent']
#       3 for i, frame in enumerate(frames):
# ----> 4     frame.to_csv(f'./data/raw/sent/{frame_labels[i]}-{datetime.now():%Y-%m-%d %H:%M:%S}.csv', sep='|')
#
# File /usr/local/Caskroom/miniconda/base/envs/data/lib/python3.9/site-packages/pandas/core/generic.py:3551, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3540 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3542 formatter = DataFrameFormatter(
#    3543     frame=df,
#    3544     header=header,
#    (...)
#    3548     decimal=decimal,
#    3549 )
# -> 3551 return DataFrameRenderer(formatter).to_csv(
#    3552     path_or_buf,
#    3553     line_terminator=line_terminator,
#    3554     sep=sep,
#    3555     encoding=encoding,
#    3556     errors=errors,
#    3557     compression=compression,
#    3558     quoting=quoting,
#    3559     columns=columns,
#    3560     index_label=index_label,
#    3561     mode=mode,
#    3562     chunksize=chunksize,
#    3563     quotechar=quotechar,
#    3564     date_format=date_format,
#    3565     doublequote=doublequote,
#    3566     escapechar=escapechar,
#    3567     storage_options=storage_options,
#    3568 )
#
# File /usr/local/Caskroom/miniconda/base/envs/data/lib/python3.9/site-packages/pandas/io/formats/format.py:1180, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1159     created_buffer = False
#    1161 csv_formatter = CSVFormatter(
#    1162     path_or_buf=path_or_buf,
#    1163     line_terminator=line_terminator,
#    (...)
#    1178     formatter=self.fmt,
#    1179 )
# -> 1180 csv_formatter.save()
#    1182 if created_buffer:
#    1183     assert isinstance(path_or_buf, StringIO)
#
# File /usr/local/Caskroom/miniconda/base/envs/data/lib/python3.9/site-packages/pandas/io/formats/csvs.py:241, in CSVFormatter.save(self)
#     237 """
#     238 Create the writer & save.
#     239 """
#     240 # apply compression and byte/text conversion
# --> 241 with get_handle(
#     242     self.filepath_or_buffer,
#     243     self.mode,
#     244     encoding=self.encoding,
#     245     errors=self.errors,
#     246     compression=self.compression,
#     247     storage_options=self.storage_options,
#     248 ) as handles:
#     249
#     250     # Note: self.encoding is irrelevant here
#     251     self.writer = csvlib.writer(
#     252         handles.handle,
#     253         lineterminator=self.line_terminator,
#    (...)
#     258         quotechar=self.quotechar,
#     259     )
#     261     self._save()
#
# File /usr/local/Caskroom/miniconda/base/envs/data/lib/python3.9/site-packages/pandas/io/common.py:697, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     695 # Only for write methods
#     696 if "r" not in mode and is_path:
# --> 697     check_parent_directory(str(handle))
#     699 if compression:
#     700     if compression != "zstd":
#     701         # compression libraries do not like an explicit text-mode
#
# File /usr/local/Caskroom/miniconda/base/envs/data/lib/python3.9/site-packages/pandas/io/common.py:571, in check_parent_directory(path)
#     569 parent = Path(path).parent
#     570 if not parent.is_dir():
# --> 571     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'data/raw/sent'
